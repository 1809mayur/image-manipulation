# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %%
# opened an image with the help of pillow library.
img = Image.open("tree.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=771x480 at 0x22E5F8249A0>

# %%
# matplotlib plot this over axises.
frame = plt.imshow(img,cmap="Accent")
frame

# %%
# Through this load() we can access the each pixels at specific position.
px = img.load()
px

# %%
px[200,200]
# Out:
# (53, 30, 72)

# %%
# converted image into array of co
img_arr = np.array(img)
img_arr.shape
# Out:
# (480, 771, 3)

# %%
# sliced the images into different shape based on their dimensions in co-ordinare system.
val = img_arr[:,200:550,2]
plt.imshow(val)

# %%
cp = img_arr.copy()
cp
# Out:
# array([[[ 7, 11, 22],
#         [ 8, 12, 23],
#         [11, 13, 25],
#         ...,
#         [10, 13, 30],
#         [10, 13, 30],
#         [ 9, 12, 29]],
#
#        [[ 7, 11, 22],
#         [10, 12, 24],
#         [12, 14, 26],
#         ...,
#         [10, 13, 30],
#         [10, 13, 30],
#         [10, 13, 30]],
#
#        [[ 8, 10, 22],
#         [10, 12, 24],
#         [13, 15, 27],
#         ...,
#         [10, 13, 30],
#         [10, 13, 30],
#         [10, 13, 30]],
#
#        ...,
#
#        [[ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         ...,
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4]],
#
#        [[ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         ...,
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4]],
#
#        [[ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         ...,
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         [ 4,  4,  4]]], dtype=uint8)

# %%
plt.imshow(cp)

# %%
cp[:,:,0] = 54
plt.imshow(cp)
